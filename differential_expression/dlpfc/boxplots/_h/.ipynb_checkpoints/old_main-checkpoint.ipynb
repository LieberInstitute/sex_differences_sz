# %% [markdown]
# # Boxplot of top five up- and downregulated genes

# %%
library(ggplot2)
library(reshape2)

# %%
pheno_file = '/ceph/projects/v3_phase3_paper/inputs/phenotypes/_m/dlpfc_phenotypes.csv'
pheno = read.csv(pheno_file, row.names=1)
head(pheno, 2)
# Out:
#        BrNum  RNum   Region  RIN Age   Sex Race Dx
# R12864 Br1303 R12864 Caudate 9.6 42.98 F   AA   Schizo
# R12865 Br1320 R12865 Caudate 9.5 53.12 M   AA   Schizo

# %% [markdown]
# ## Load residualized expression

# %%
res_file = '../../_m/genes/residualized_expression.tsv'
resdf = t(read.delim(res_file, row.names=1))
resdf[1:2, 1:3]
# Out:
#        ENSG00000227232.5 ENSG00000278267.1 ENSG00000279457.3
# R12864 -0.3107924        0.9891557          0.5516736
# R12865 -1.1152005        0.2539395         -0.1254856

# %% [markdown]
# ## Overall
# ### Differential expressed genes

# %%
genes = read.delim('../../_m/genes/diffExpr_maleVfemale_full.txt')
genes['Feature'] = row.names(genes)
genes = subset(genes, adj.P.Val < 0.01, 
               select=c(Feature, ensemblID, Symbol, logFC, adj.P.Val))
head(genes, 2)
# Out:
#                    Feature            ensemblID       Symbol logFC
# ENSG00000114374.12 ENSG00000114374.12 ENSG00000114374 USP9Y   8.848016
# ENSG00000229807.10 ENSG00000229807.10 ENSG00000229807 XIST   -9.376184
#                    adj.P.Val
# ENSG00000114374.12 5.680316e-302
# ENSG00000229807.10 2.021540e-298

# %% [markdown]
# ### Upregulated

# %%
up_genes = subset(genes, logFC > 0)
up_genes['Dir'] = 'Up'
sigUp_genes = head(up_genes, 5)
sigUp_genes = droplevels(sigUp_genes)

for(xx in seq_along(sigUp_genes$Symbol)){
    if(sigUp_genes$Symbol[xx] == ''){
        sigUp_genes$New_ID[xx] = paste0(sigUp_genes$ensemblID[xx], '\nlogFC: ', 
                                sprintf("%.2f", sigUp_genes$logFC[xx]), ' FDR: ', 
                                sprintf("%.2e", sigUp_genes$adj.P.Val[xx]))
    } else {
        sigUp_genes$New_ID[xx] = paste0(sigUp_genes$Symbol[xx], '\nlogFC: ', 
                                sprintf("%.2f", sigUp_genes$logFC[xx]), ' FDR: ', 
                                sprintf("%.2e", sigUp_genes$adj.P.Val[xx]))
    }
}

sigUp_genes$New_ID = as.factor(sigUp_genes$New_ID)
sigUp_genes$New_ID = with(sigUp_genes, reorder(New_ID, adj.P.Val, median))
sigUp_genes
# Out:
#                    Feature            ensemblID       Symbol logFC
# ENSG00000114374.12 ENSG00000114374.12 ENSG00000114374 USP9Y  8.848016
# ENSG00000183878.15 ENSG00000183878.15 ENSG00000183878 UTY    8.753539
# ENSG00000012817.15 ENSG00000012817.15 ENSG00000012817 KDM5D  8.859649
# ENSG00000067048.16 ENSG00000067048.16 ENSG00000067048 DDX3Y  8.736237
# ENSG00000131002.11 ENSG00000131002.11 ENSG00000131002 TXLNGY 8.765071
#                    adj.P.Val     Dir New_ID
# ENSG00000114374.12 5.680316e-302 Up  USP9Y\nlogFC: 8.85 FDR: 5.68e-302
# ENSG00000183878.15 1.234760e-275 Up  UTY\nlogFC: 8.75 FDR: 1.23e-275
# ENSG00000012817.15 5.994448e-274 Up  KDM5D\nlogFC: 8.86 FDR: 5.99e-274
# ENSG00000067048.16 8.787978e-268 Up  DDX3Y\nlogFC: 8.74 FDR: 8.79e-268
# ENSG00000131002.11 3.373759e-255 Up  TXLNGY\nlogFC: 8.77 FDR: 3.37e-255

# %%
df1 = data.frame(resdf[, rownames(sigUp_genes)])
df1['RNum'] = row.names(df1)
df1 = melt(df1, id.vars="RNum", value.name = "res", variable.name="Feature")
head(df1, 2)
# Out:
#   RNum   Feature            res
# 1 R12864 ENSG00000114374.12 -1.4213337
# 2 R12865 ENSG00000114374.12  0.6472526

# %%
df1 = merge(df1, sigUp_genes, by='Feature')
head(df1, 2)
# Out:
#   Feature            RNum   res        ensemblID       Symbol logFC
# 1 ENSG00000012817.15 R12864 -1.3124525 ENSG00000012817 KDM5D  8.859649
# 2 ENSG00000012817.15 R12865  0.6754881 ENSG00000012817 KDM5D  8.859649
#   adj.P.Val     Dir New_ID
# 1 5.994448e-274 Up  KDM5D\nlogFC: 8.86 FDR: 5.99e-274
# 2 5.994448e-274 Up  KDM5D\nlogFC: 8.86 FDR: 5.99e-274

# %% [markdown]
# #### Merge data with phenotypes

# %%
bigdf1 = merge(pheno, df1, by='RNum')
levels(bigdf1$Sex) <- c("Female", "Male")
dim(bigdf1)
# Out:
# [1] 1945   16

# %% [markdown]
# #### Plot genes

# %%
pjd = position_jitterdodge(jitter.width=1.0)
pp = (ggplot(bigdf1, aes(x=Sex, y=res, fill=Sex)) + geom_boxplot(alpha=0.2, outlier.alpha=0) + 
      geom_jitter(position=pjd, stroke=0, alpha=0.4, aes(color=Sex)) + ylim(-2.5, 1) + 
      labs(x='Gender', y='Residual Expression') + facet_grid('Dir~New_ID') +
      stat_summary(geom='point', position='identity', fun.y=median, fill='black') + 
      theme_bw() + theme(axis.text.x=element_blank(), axis.text.y=element_text(size=20), 
                         axis.title.y=element_text(size=24, face='bold'), axis.title.x=element_blank(),
                         strip.text.x=element_text(size=20), strip.text.y=element_blank(), 
                         legend.text=element_text(size=32), legend.title=element_blank(), 
                         legend.position="bottom", panel.grid=element_blank()))
pp
# Out:
# plot without title

# %%
ggsave(pp, filename = 'top5_upregulated_boxplot.pdf', width=20, height=8)
ggsave(pp, filename = 'top5_upregulated_boxplot.svg', width=20, height=8)
ggsave(pp, filename = 'top5_upregulated_boxplot.png', width=20, height=8)

# %% [markdown]
# ### Downregulated

# %%
down_genes = subset(genes, logFC < 0)
down_genes['Dir'] = 'Down'
sigDown_genes = head(down_genes, 5)
sigDown_genes = droplevels(sigDown_genes)

for(xx in seq_along(sigDown_genes$Symbol)){
    if(sigDown_genes$Symbol[xx] == ''){
        sigDown_genes$New_ID[xx] = paste0(sigDown_genes$ensemblID[xx], '\nlogFC: ', 
                                sprintf("%.2f", sigDown_genes$logFC[xx]), ' FDR: ', 
                                sprintf("%.2e", sigDown_genes$adj.P.Val[xx]))
    } else {
        sigDown_genes$New_ID[xx] = paste0(sigDown_genes$Symbol[xx], '\nlogFC: ', 
                                sprintf("%.2f", sigDown_genes$logFC[xx]), ' FDR: ', 
                                sprintf("%.2e", sigDown_genes$adj.P.Val[xx]))
    }
}

sigDown_genes$New_ID = as.factor(sigDown_genes$New_ID)
sigDown_genes$New_ID = with(sigDown_genes, reorder(New_ID, adj.P.Val, median))
sigDown_genes
# Out:
#                    Feature            ensemblID       Symbol logFC
# ENSG00000229807.10 ENSG00000229807.10 ENSG00000229807 XIST   -9.2707604
# ENSG00000005889.15 ENSG00000005889.15 ENSG00000005889 ZFX    -0.6305951
# ENSG00000126012.11 ENSG00000126012.11 ENSG00000126012 KDM5C  -0.4969340
# ENSG00000147050.14 ENSG00000147050.14 ENSG00000147050 KDM6A  -0.5425694
# ENSG00000130021.13 ENSG00000130021.13 ENSG00000130021 PUDP   -0.6124284
#                    adj.P.Val     Dir  New_ID
# ENSG00000229807.10 5.194590e-265 Down XIST\nlogFC: -9.27 FDR: 5.19e-265
# ENSG00000005889.15 2.002576e-193 Down ZFX\nlogFC: -0.63 FDR: 2.00e-193
# ENSG00000126012.11 2.053679e-143 Down KDM5C\nlogFC: -0.50 FDR: 2.05e-143
# ENSG00000147050.14 2.542892e-123 Down KDM6A\nlogFC: -0.54 FDR: 2.54e-123
# ENSG00000130021.13  1.908800e-95 Down PUDP\nlogFC: -0.61 FDR: 1.91e-95

# %%
df2 = data.frame(resdf[, rownames(sigDown_genes)])
df2['RNum'] = row.names(df2)
df2 = melt(df2, id.vars="RNum", value.name = "res", variable.name="Feature")
head(df2, 2)
# Out:
#   RNum   Feature            res
# 1 R12864 ENSG00000229807.10  1.412867
# 2 R12865 ENSG00000229807.10 -1.096965

# %%
df2 = merge(df2, sigDown_genes, by='Feature')
head(df2, 2)
# Out:
#   Feature            RNum   res        ensemblID       Symbol logFC
# 1 ENSG00000005889.15 R12864  2.0302914 ENSG00000005889 ZFX    -0.6305951
# 2 ENSG00000005889.15 R12865 -0.3609201 ENSG00000005889 ZFX    -0.6305951
#   adj.P.Val     Dir  New_ID
# 1 2.002576e-193 Down ZFX\nlogFC: -0.63 FDR: 2.00e-193
# 2 2.002576e-193 Down ZFX\nlogFC: -0.63 FDR: 2.00e-193

# %% [markdown]
# #### Merge data with phenotypes

# %%
bigdf2 = merge(pheno, df2, by='RNum')
levels(bigdf2$Sex) <- c("Female", "Male")
dim(bigdf2)
# Out:
# [1] 1955   16

# %% [markdown]
# #### Plot genes

# %%
pjd = position_jitterdodge(jitter.width=1.0)
qq = (ggplot(bigdf2, aes(x=Sex, y=res, fill=Sex)) + geom_boxplot(alpha=0.2, outlier.alpha=0) + 
      geom_jitter(position=pjd, stroke=0, alpha=0.4, aes(color=Sex)) + 
      labs(x='Diagnosis', y='Residual Expression') + facet_grid('Dir~New_ID') +
      stat_summary(geom='point', position='identity', fun.y=median, fill='black') + 
      theme_bw() + theme(axis.text.x=element_blank(), axis.text.y=element_text(size=20), 
                         axis.title.y=element_text(size=24, face='bold'), axis.title.x=element_blank(),
                         strip.text.x=element_text(size=20), strip.text.y=element_blank(), 
                         legend.text=element_text(size=32), legend.title=element_blank(), 
                         legend.position="bottom", panel.grid=element_blank()))
qq
# Out:
# plot without title

# %%
ggsave(qq, filename = 'top5_downregulated_boxplot.pdf', width=20, height=8)
ggsave(qq, filename = 'top5_downregulated_boxplot.svg', width=20, height=8)
ggsave(qq, filename = 'top5_downregulated_boxplot.png', width=20, height=8)

# %% [markdown]
# ## Autosomal only

# %% [markdown]
# ### Differential expressed genes

# %%
genes = read.csv('../../metrics_summary/_m/autosomal_DEG.csv')
row.names(genes) <- genes$Feature
genes = genes[order(genes$adj.P.Val), ]
head(genes, 2)
# Out:
#                   Feature           chr   Symbol    ensemblID       logFC
# ENSG00000205611.4 ENSG00000205611.4 chr20 LINC01597 ENSG00000205611 1.251392
# ENSG00000283443.1 ENSG00000283443.1 chr20 chr?      ENSG00000283443 1.342952
#                   adj.P.Val    Type
# ENSG00000205611.4 1.339006e-16 gene
# ENSG00000283443.1 3.772753e-16 gene

# %% [markdown]
# ### Upregulated

# %%
up_genes = subset(genes, logFC > 0)
up_genes['Dir'] = 'Up'
sigUp_genes = head(up_genes, 5)
sigUp_genes = droplevels(sigUp_genes)

for(xx in seq_along(sigUp_genes$Symbol)){
    if(sigUp_genes$Symbol[xx] == '' | sigUp_genes$Symbol[xx] == 'chr?'){
        sigUp_genes$New_ID[xx] = paste0(sigUp_genes$ensemblID[xx], '\nlogFC: ', 
                                sprintf("%.2f", sigUp_genes$logFC[xx]), ' FDR: ', 
                                sprintf("%.2e", sigUp_genes$adj.P.Val[xx]))
    } else {
        sigUp_genes$New_ID[xx] = paste0(sigUp_genes$Symbol[xx], '\nlogFC: ', 
                                sprintf("%.2f", sigUp_genes$logFC[xx]), ' FDR: ', 
                                sprintf("%.2e", sigUp_genes$adj.P.Val[xx]))
    }
}

sigUp_genes$New_ID = as.factor(sigUp_genes$New_ID)
sigUp_genes$New_ID = with(sigUp_genes, reorder(New_ID, adj.P.Val, median))
sigUp_genes
# Out:
#                    Feature            chr   Symbol    ensemblID       logFC
# ENSG00000205611.4  ENSG00000205611.4  chr20 LINC01597 ENSG00000205611 1.2513920
# ENSG00000283443.1  ENSG00000283443.1  chr20 chr?      ENSG00000283443 1.3429525
# ENSG00000149531.15 ENSG00000149531.15 chr20 FRG1BP    ENSG00000149531 0.6270650
# ENSG00000282826.1  ENSG00000282826.1  chr20 FRG1CP    ENSG00000282826 0.5270625
# ENSG00000258484.3  ENSG00000258484.3  chr15 SPESP1    ENSG00000258484 0.7543695
#                    adj.P.Val    Type Dir
# ENSG00000205611.4  1.339006e-16 gene Up
# ENSG00000283443.1  3.772753e-16 gene Up
# ENSG00000149531.15 3.881405e-15 gene Up
# ENSG00000282826.1  2.222138e-14 gene Up
# ENSG00000258484.3  2.676319e-12 gene Up
#                    New_ID
# ENSG00000205611.4  LINC01597\nlogFC: 1.25 FDR: 1.34e-16
# ENSG00000283443.1  ENSG00000283443\nlogFC: 1.34 FDR: 3.77e-16
# ENSG00000149531.15 FRG1BP\nlogFC: 0.63 FDR: 3.88e-15
# ENSG00000282826.1  FRG1CP\nlogFC: 0.53 FDR: 2.22e-14
# ENSG00000258484.3  SPESP1\nlogFC: 0.75 FDR: 2.68e-12

# %%
df1 = data.frame(resdf[, rownames(sigUp_genes)])
df1['RNum'] = row.names(df1)
df1 = melt(df1, id.vars="RNum", value.name = "res", variable.name="Feature")
head(df1, 2)
# Out:
#   RNum   Feature           res
# 1 R12864 ENSG00000205611.4 -3.5896995
# 2 R12865 ENSG00000205611.4  0.8170862

# %%
df1 = merge(df1, sigUp_genes, by='Feature')
head(df1, 2)
# Out:
#   Feature            RNum   res        chr   Symbol ensemblID       logFC
# 1 ENSG00000149531.15 R12864 -3.8148016 chr20 FRG1BP ENSG00000149531 0.627065
# 2 ENSG00000149531.15 R12865  0.9983621 chr20 FRG1BP ENSG00000149531 0.627065
#   adj.P.Val    Type Dir New_ID
# 1 3.881405e-15 gene Up  FRG1BP\nlogFC: 0.63 FDR: 3.88e-15
# 2 3.881405e-15 gene Up  FRG1BP\nlogFC: 0.63 FDR: 3.88e-15

# %% [markdown]
# #### Merge data with phenotypes

# %%
bigdf1 = merge(pheno, df1, by='RNum')
levels(bigdf1$Sex) <- c("Female", "Male")
dim(bigdf1)
# Out:
# [1] 1955   18

# %% [markdown]
# #### Plot genes

# %%
pjd = position_jitterdodge(jitter.width=1.0)
pp = (ggplot(bigdf1, aes(x=Sex, y=res, fill=Sex)) + geom_boxplot(alpha=0.2, outlier.alpha=0) + 
      geom_jitter(position=pjd, stroke=0, alpha=0.4, aes(color=Sex)) + 
      labs(x='Gender', y='Residual Expression') + facet_grid('Dir~New_ID') +
      stat_summary(geom='point', position='identity', fun.y=median, fill='black') + 
      theme_bw() + theme(axis.text.x=element_blank(), axis.text.y=element_text(size=20), 
                         axis.title.y=element_text(size=24, face='bold'), axis.title.x=element_blank(),
                         strip.text.x=element_text(size=18), strip.text.y=element_blank(), 
                         legend.text=element_text(size=32), legend.title=element_blank(), 
                         legend.position="bottom", panel.grid=element_blank()))
pp
# Out:
# plot without title

# %%
ggsave(pp, filename = 'top5_upregulated_boxplot_autosomal.pdf', width=20, height=10)
ggsave(pp, filename = 'top5_upregulated_boxplot_autosomal.svg', width=20, height=10)
ggsave(pp, filename = 'top5_upregulated_boxplot_autosomal.png', width=20, height=10)

# %% [markdown]
# ### Downregulated

# %%
down_genes = subset(genes, logFC < 0)
down_genes['Dir'] = 'Down'
sigDown_genes = head(down_genes, 5)
sigDown_genes = droplevels(sigDown_genes)

for(xx in seq_along(sigDown_genes$Symbol)){
    if(sigDown_genes$Symbol[xx] == '' | sigDown_genes$Symbol[xx] == 'chr?'){
        sigDown_genes$New_ID[xx] = paste0(sigDown_genes$ensemblID[xx], '\nlogFC: ', 
                                sprintf("%.2f", sigDown_genes$logFC[xx]), ' FDR: ', 
                                sprintf("%.2e", sigDown_genes$adj.P.Val[xx]))
    } else {
        sigDown_genes$New_ID[xx] = paste0(sigDown_genes$Symbol[xx], '\nlogFC: ', 
                                sprintf("%.2f", sigDown_genes$logFC[xx]), ' FDR: ', 
                                sprintf("%.2e", sigDown_genes$adj.P.Val[xx]))
    }
}

sigDown_genes$New_ID = as.factor(sigDown_genes$New_ID)
sigDown_genes$New_ID = with(sigDown_genes, reorder(New_ID, adj.P.Val, median))
sigDown_genes
# Out:
#                   Feature           chr   Symbol   ensemblID       logFC
# ENSG00000095932.6 ENSG00000095932.6 chr19 SMIM24   ENSG00000095932 -0.8950783
# ENSG00000236698.1 ENSG00000236698.1 chr1  EIF1AXP1 ENSG00000236698 -0.2522452
# ENSG00000180574.3 ENSG00000180574.3 chr12 chr?     ENSG00000180574 -0.2357274
# ENSG00000261600.1 ENSG00000261600.1 chr2  chr?     ENSG00000261600 -0.9580316
# ENSG00000241532.1 ENSG00000241532.1 chr3  AGGF1P3  ENSG00000241532 -0.7486820
#                   adj.P.Val    Type Dir
# ENSG00000095932.6 8.056283e-16 gene Down
# ENSG00000236698.1 2.293191e-15 gene Down
# ENSG00000180574.3 1.372454e-12 gene Down
# ENSG00000261600.1 3.314604e-12 gene Down
# ENSG00000241532.1 1.168431e-11 gene Down
#                   New_ID
# ENSG00000095932.6 SMIM24\nlogFC: -0.90 FDR: 8.06e-16
# ENSG00000236698.1 EIF1AXP1\nlogFC: -0.25 FDR: 2.29e-15
# ENSG00000180574.3 ENSG00000180574\nlogFC: -0.24 FDR: 1.37e-12
# ENSG00000261600.1 ENSG00000261600\nlogFC: -0.96 FDR: 3.31e-12
# ENSG00000241532.1 AGGF1P3\nlogFC: -0.75 FDR: 1.17e-11

# %%
df2 = data.frame(resdf[, rownames(sigDown_genes)])
df2['RNum'] = row.names(df2)
df2 = melt(df2, id.vars="RNum", value.name = "res", variable.name="Feature")
head(df2, 2)
# Out:
#   RNum   Feature           res
# 1 R12864 ENSG00000095932.6  0.6271815
# 2 R12865 ENSG00000095932.6 -0.6234093

# %%
df2 = merge(df2, sigDown_genes, by='Feature')
head(df2, 2)
# Out:
#   Feature           RNum   res        chr   Symbol ensemblID       logFC
# 1 ENSG00000095932.6 R12864  0.6271815 chr19 SMIM24 ENSG00000095932 -0.8950783
# 2 ENSG00000095932.6 R12865 -0.6234093 chr19 SMIM24 ENSG00000095932 -0.8950783
#   adj.P.Val    Type Dir  New_ID
# 1 8.056283e-16 gene Down SMIM24\nlogFC: -0.90 FDR: 8.06e-16
# 2 8.056283e-16 gene Down SMIM24\nlogFC: -0.90 FDR: 8.06e-16

# %% [markdown]
# #### Merge data with phenotypes

# %%
bigdf2 = merge(pheno, df2, by='RNum')
levels(bigdf2$Sex) <- c("Female", "Male")
dim(bigdf2)
# Out:
# [1] 1955   18

# %% [markdown]
# #### Plot genes

# %%
pjd = position_jitterdodge(jitter.width=1.0)
qq = (ggplot(bigdf2, aes(x=Sex, y=res, fill=Sex)) + geom_boxplot(alpha=0.2, outlier.alpha=0) + 
      geom_jitter(position=pjd, stroke=0, alpha=0.4, aes(color=Sex)) + 
      labs(x='Diagnosis', y='Residual Expression') + facet_grid('Dir~New_ID') +
      stat_summary(geom='point', position='identity', fun.y=median, fill='black') + 
      theme_bw() + theme(axis.text.x=element_blank(), axis.text.y=element_text(size=20), 
                         axis.title.y=element_text(size=24, face='bold'), axis.title.x=element_blank(),
                         strip.text.x=element_text(size=18), strip.text.y=element_blank(), 
                         legend.text=element_text(size=32), legend.title=element_blank(), 
                         legend.position="bottom", panel.grid=element_blank()))
qq
# Out:
# plot without title

# %%
ggsave(qq, filename = 'top5_downregulated_boxplot_autosomal.pdf', width=20, height=10)
ggsave(qq, filename = 'top5_downregulated_boxplot_autosomal.svg', width=20, height=10)
ggsave(qq, filename = 'top5_downregulated_boxplot_autosomal.png', width=20, height=10)

# %% [markdown]
# ## Session Info

# %%
Sys.time()
proc.time()
options(width = 120)
sessioninfo::session_info()
