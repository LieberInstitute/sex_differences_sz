# %% [markdown]
# # Heatmap of sharing

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from rpy2.robjects import r, pandas2ri

# %%
pandas2ri.activate()

# %% [markdown]
# ## Sign match only

# %% [markdown]
# ### Genes

# %%
mat = r('''load("../../_m/genes/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2, factor=0)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#              Caudate  DLPFC  Hippocampus
# Caudate          1.0    1.0          1.0
# DLPFC            1.0    1.0          1.0
# Hippocampus      1.0    1.0          1.0

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_signOnly_gene.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_signOnly_gene.png")

# %% [markdown]
# ### Transcripts

# %%
mat = r('''load("../../_m/transcripts/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2, factor=0)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.998077          1.0
# DLPFC        0.998077  1.000000          1.0
# Hippocampus  1.000000  1.000000          1.0

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_signOnly_tx.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_signOnly_tx.png")

# %% [markdown]
# ### Exons

# %%
mat = r('''load("../../_m/exons/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2, factor=0)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.989175     0.990476
# DLPFC        0.989175  1.000000     1.000000
# Hippocampus  0.990476  1.000000     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_signOnly_exon.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_signOnly_exon.png")

# %% [markdown]
# ### Junctions

# %%
mat = r('''load("../../_m/junctions/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2, factor=0)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.991266     0.991228
# DLPFC        0.991266  1.000000     1.000000
# Hippocampus  0.991228  1.000000     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_signOnly_jxn.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_signOnly_jxn.png")

# %% [markdown]
# ## Factor 0.5

# %% [markdown]
# ### Genes

# %%
mat = r('''load("../../_m/genes/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.960784     0.960784
# DLPFC        0.960784  1.000000     1.000000
# Hippocampus  0.960784  1.000000     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_gene.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_gene.png")

# %% [markdown]
# ### Transcripts

# %%
mat = r('''load("../../_m/transcripts/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.971154     0.969231
# DLPFC        0.971154  1.000000     1.000000
# Hippocampus  0.969231  1.000000     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_tx.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_tx.png")

# %% [markdown]
# ### Exons

# %%
mat = r('''load("../../_m/exons/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.929635     0.927891
# DLPFC        0.929635  1.000000     0.998192
# Hippocampus  0.927891  0.998192     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_exon.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_exon.png")

# %% [markdown]
# ### Junctions

# %%
mat = r('''load("../../_m/junctions/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate   DLPFC  Hippocampus
# Caudate      1.000000  0.9869     0.986842
# DLPFC        0.986900  1.0000     0.995000
# Hippocampus  0.986842  0.9950     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_jxn.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_jxn.png")

# %% [markdown]
# ## Factor 0.99

# %% [markdown]
# ### Genes

# %%
mat = r('''load("../../_m/genes/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2, factor=0.99)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.515406     0.512605
# DLPFC        0.515406  1.000000     0.974170
# Hippocampus  0.512605  0.974170     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_gene_effect99.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_gene_effect99.png")

# %% [markdown]
# ### Transcripts

# %%
mat = r('''load("../../_m/transcripts/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2, factor=0.99)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.492308     0.496154
# DLPFC        0.492308  1.000000     0.929078
# Hippocampus  0.496154  0.929078     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_tx_effect99.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_tx_effect99.png")

# %% [markdown]
# ### Exons

# %%
mat = r('''load("../../_m/exons/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2, factor=0.99)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.654939     0.631293
# DLPFC        0.654939  1.000000     0.969259
# Hippocampus  0.631293  0.969259     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_exon_effect99.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_exon_effect99.png")

# %% [markdown]
# ### Junctions

# %%
mat = r('''load("../../_m/junctions/mashr_meta_results.RData"); mashr::get_pairwise_sharing(m2, factor=0.99)''')
df = pd.DataFrame(np.array(mat), index=["Caudate", "DLPFC", "Hippocampus"], 
                  columns=["Caudate", "DLPFC", "Hippocampus"])
df
# Out:
#               Caudate     DLPFC  Hippocampus
# Caudate      1.000000  0.659389     0.671053
# DLPFC        0.659389  1.000000     0.810000
# Hippocampus  0.671053  0.810000     1.000000

# %%
sns.set(font_scale=2)
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,10))
chart = sns.heatmap(df, ax=ax, vmin=0, vmax=1, 
                    annot=True, cbar_ax=cbar_ax,
                    cbar_kws={"orientation": "horizontal"})
chart.set_yticklabels(chart.get_yticklabels(), fontweight="bold")
chart.set_xticklabels(chart.get_xticklabels(), fontweight="bold")
sns_plot = chart.get_figure()
sns_plot.savefig("eQTL_sharing_heatmap_jxn_effect99.pdf")
sns_plot.savefig("eQTL_sharing_heatmap_jxn_effect99.png")
