# %% [markdown]
# # Differential Expression with limma-voom pipeline - Genes

# %%
suppressMessages({library(ggplot2)
                  library(limma)
                  library(edgeR)
                  library(sva)
                  library(dplyr)
                  library(data.table)})

# %% [markdown]
# ## Prepare Data

# %%
pheno_file = '/ceph/users/jbenja13/projects/sex_sz_ria/input/commonMind/phenotypes/combine_files/_m/CMC_phenotypes_all.csv'
pheno = read.csv(pheno_file, stringsAsFactors = F) %>% filter(Dx %in% c('Control', 'SCZ') & 
                                                              Age.of.Death > 17 & Sex %in% c('XX', 'XY'))
pheno[1:2, 1:10]
dim(pheno)
# Out:
#   Individual_ID RNAseq.Sample_RNA_ID  Genotypes.Genotyping_Sample_ID
# 1 CMC_HBCC_003  CMC_HBCC_RNA_PFC_3158 4040296003_A
# 2 CMC_HBCC_006  CMC_HBCC_RNA_PFC_3162 4572348358_R01C02
#   Institution Dx      Reported.Gender Sex Ethnicity
# 1 NIMH-HBCC   Control Male            XY  Caucasian
# 2 NIMH-HBCC   Control Male            XY  African-American
#   Brain.Weight..in.grams. PMI..in.hours.
# 1 1500                    13
# 2 1250                    44
# [1] 814  47

# %% [markdown]
# ### Load genotype data

# %%
mds_file = '/ceph/users/jbenja13/projects/sex_sz_ria/input/commonMind/genotypes/mds/_m/CMC_MSSM-Penn-Pitt_DLPFC_QC.mds'
mds = fread(mds_file, data.table=F)
colnames(mds) = gsub('C', 'snpPC', colnames(mds))
head(mds)
# Out:
#   FID IID     SOL snpPC1      snpPC2      snpPC3      snpPC4       snpPC5
# 1 0   MSSM_13 0   -0.02226900 -0.00960189  0.00398743  0.000288773 -0.002412270
# 2 0   MSSM_25 0   -0.02111640 -0.00721966  0.00368005 -0.002035680  0.000947013
# 3 0   MSSM_48 0   -0.01533570  0.02725110 -0.00141831 -0.001310480 -0.007791530
# 4 0   MSSM_59 0   -0.01580840  0.01177670  0.00187047  0.003407890  0.015133700
# 5 0   MSSM_83 0    0.00730839 -0.00423147 -0.03097030  0.016012400  0.002320820
# 6 0   MSSM_2  0   -0.01586000  0.02460900 -0.00221120 -0.001457290 -0.005850930
#   snpPC6       snpPC7      snpPC8       snpPC9       snpPC10
# 1  0.003863710 -0.00645592  2.05686e-05 -0.003564570  0.003195170
# 2  0.002865670  0.00380275 -8.09738e-04  0.002788260  0.000883054
# 3  0.000903945  0.00386361 -9.29096e-04  0.000432877  0.002867700
# 4 -0.011008300 -0.00251472  1.15840e-03 -0.004319110 -0.003293370
# 5 -0.000923755  0.00224721  9.01862e-03  0.000747573  0.001278140
# 6  0.002230790  0.00103045  1.68320e-03 -0.000216837  0.001251180

# %%
new_pheno = merge(pheno, mds, by.y='IID', by.x='Genotypes.Genotyping_Sample_ID')
new_pheno$Dx = factor(new_pheno$Dx, levels = c("Control", "SCZ"))
new_pheno$Sex <- factor(new_pheno$Sex)
head(new_pheno, 2)
# Out:
#   Genotypes.Genotyping_Sample_ID Individual_ID RNAseq.Sample_RNA_ID Institution
# 1 MSSM_1                         CMC_MSSM_025  MSSM_RNA_PFC_1       MSSM
# 2 MSSM_10                        CMC_MSSM_026  MSSM_RNA_PFC_10      MSSM
#   Dx      Reported.Gender Sex Ethnicity Brain.Weight..in.grams. PMI..in.hours.
# 1 SCZ     Male            XY  Caucasian 1216                     8.9
# 2 Control Male            XY  Hispanic  1238                    12.3
#   <U+22EF>   snpPC1      snpPC2      snpPC3      snpPC4      snpPC5
# 1 <U+22EF> -0.02072340 -0.00621056  0.00332806 0.000395088  0.00398844
# 2 <U+22EF> -0.00419867 -0.01177810 -0.08272160 0.019969900 -0.01176620
#   snpPC6      snpPC7      snpPC8       snpPC9      snpPC10
# 1 -0.00191427 -0.00683373 -0.000160904 -0.00162913 -0.00323322
# 2  0.00431321  0.00633604 -0.009369610 -0.00082994 -0.00336866

# %%
ggplot(new_pheno, aes(x=Dx, y=RIN, fill=Dx)) + geom_boxplot() + geom_jitter()
# Out:
# plot without title

# %%
ggplot(new_pheno, aes(x=Dx, y=Expression_Profiling_Efficiency, fill=Dx)) + geom_boxplot() + geom_jitter()
# Out:
# plot without title

# %%
table(new_pheno$Sex)
# Out:
#  XX  XY
# 220 325

# %%
table(new_pheno$Brodmann_Area)
# Out:
#   9  46
# 543   2

# %%
new_pheno = new_pheno %>% mutate(Age=replace(new_pheno$Age.of.Death, new_pheno$Age.of.Death == '90+', '91')) %>% filter(Brodmann_Area == '9')
new_pheno$Age = as.numeric(new_pheno$Age)

# %% [markdown]
# ### Load gene counts

# %%
counts_file = '/ceph/users/jbenja13/projects/sex_sz_ria/input/commonMind/counts/_m/CMC_MSSM-Penn-Pitt_DLPFC_rsem_genes_expected_count.tsv'
counts = fread(counts_file, data.table=FALSE)
rownames(counts) = counts[, 1]
counts[1:5, 1:5]
# Out:
#                    gene_id
# ENSG00000000003.14 ENSG00000000003.14
# ENSG00000000005.5  ENSG00000000005.5
# ENSG00000000419.12 ENSG00000000419.12
# ENSG00000000457.13 ENSG00000000457.13
# ENSG00000000460.16 ENSG00000000460.16
#                    transcript_id.s.
# ENSG00000000003.14 ENST00000373020.8,ENST00000494424.1,ENST00000496771.5,ENST00000612152.4,ENST00000614008.4
# ENSG00000000005.5  ENST00000373031.4,ENST00000485971.1
# ENSG00000000419.12 ENST00000371582.8,ENST00000371584.8,ENST00000371588.9,ENST00000413082.1,ENST00000466152.5,ENST00000494752.1
# ENSG00000000457.13 ENST00000367770.5,ENST00000367771.10,ENST00000367772.8,ENST00000423670.1,ENST00000470238.1
# ENSG00000000460.16 ENST00000286031.10,ENST00000359326.8,ENST00000413811.3,ENST00000459772.5,ENST00000466580.6,ENST00000472795.5,ENST00000481744.5,ENST00000496973.5,ENST00000498289.5
#                    MSSM_RNA_BP_PFC_2 MSSM_RNA_BP_PFC_4 MSSM_RNA_BP_PFC_5
# ENSG00000000003.14 159.00            113.00            175.00
# ENSG00000000005.5    2.00              1.00              1.00
# ENSG00000000419.12 347.00            203.00            258.00
# ENSG00000000457.13 312.63            201.33            259.89
# ENSG00000000460.16  95.37             70.67             93.11

# %%
annot = counts[, 1:2]
head(annot, 2)
# Out:
#                    gene_id
# ENSG00000000003.14 ENSG00000000003.14
# ENSG00000000005.5  ENSG00000000005.5
#                    transcript_id.s.
# ENSG00000000003.14 ENST00000373020.8,ENST00000494424.1,ENST00000496771.5,ENST00000612152.4,ENST00000614008.4
# ENSG00000000005.5  ENST00000373031.4,ENST00000485971.1

# %%
new_counts = merge(t(counts[, -1:-2]), new_pheno, by.x=0, by.y='RNAseq.Sample_RNA_ID')

row.names(new_counts) = new_counts[, 'Row.names']
new_counts = new_counts %>% select(-c(colnames(new_pheno)[colnames(new_pheno)!= 'RNAseq.Sample_RNA_ID'], 'Row.names'))
new_counts = t(new_counts)
new_counts[1:2, 1:5]
dim(new_counts)
# Out:
#                    MSSM_RNA_PFC_1 MSSM_RNA_PFC_10 MSSM_RNA_PFC_100
# ENSG00000000003.14 124            307             242
# ENSG00000000005.5    1              2               1
#                    MSSM_RNA_PFC_101 MSSM_RNA_PFC_102
# ENSG00000000003.14 99               196
# ENSG00000000005.5   1                 4
# [1] 58347   543

# %% [markdown]
# ### Generate DGEList

# %%
x <- DGEList(counts=new_counts, 
             genes=annot, 
             samples=new_pheno)

# %% [markdown]
# ### Filtering low counts

# %%
design0 <- model.matrix(~Dx*Sex, data=x$samples)
keep.x <- filterByExpr(x, design=design0)
x <- x[keep.x, , keep.lib.sizes=FALSE]
print(paste('There are:', sum(keep.x), 'features left!', sep=' '))
# Out:
# [1] "There are: 21949 features left!"

# %% [markdown]
# ### Normalize counts

# %%
x <- calcNormFactors(x, method="TMM")

# %% [markdown]
# ## Differential Expression Analysis

# %% [markdown]
# ### Design matrix

# %%
mod = model.matrix(~Dx*Sex + Age + RIN + rRNA_Rate + Percent_Aligned + Institution +
                   Expression_Profiling_Efficiency + 
                   snpPC1 + snpPC2 + snpPC3 + snpPC4 + snpPC5, data = new_pheno)

colnames(mod) <- gsub("Dx", "", colnames(mod))
colnames(mod) <- gsub("SexXY", "Male", colnames(mod))
colnames(mod) <- gsub(":", "_", colnames(mod))
colnames(mod) <- gsub("\\(Intercept\\)", "Intercept",
                         colnames(mod))

head(mod, 2)
# Out:
#   Intercept SCZ Male Age RIN rRNA_Rate    Percent_Aligned InstitutionPenn
# 1 1         1   1    68  7.5 0.0004665723 0.9543849       0
# 2 1         0   1    58  8.8 0.0002741816 0.9767313       0
#   InstitutionPitt Expression_Profiling_Efficiency snpPC1      snpPC2
# 1 0               0.3612353                       -0.02072340 -0.00621056
# 2 0               0.6410191                       -0.00419867 -0.01177810
#   snpPC3      snpPC4      snpPC5      SCZ_Male
# 1  0.00332806 0.000395088  0.00398844 1
# 2 -0.08272160 0.019969900 -0.01176620 0

# %% [markdown]
# ### Calculate SVAs

# %%
null.model = as.matrix(as.data.frame(mod)[, !(names(as.data.frame(mod)) %in% c("Male", "SCZ", "SCZ_Male"))])
head(null.model, 2)
# Out:
#   Intercept SCZ Age RIN rRNA_Rate    Percent_Aligned InstitutionPenn
# 1 1         1   68  7.5 0.0004665723 0.9543849       0
# 2 1         0   58  8.8 0.0002741816 0.9767313       0
#   InstitutionPitt Expression_Profiling_Efficiency snpPC1      snpPC2
# 1 0               0.3612353                       -0.02072340 -0.00621056
# 2 0               0.6410191                       -0.00419867 -0.01177810
#   snpPC3      snpPC4      snpPC5
# 1  0.00332806 0.000395088  0.00398844
# 2 -0.08272160 0.019969900 -0.01176620

# %%
print(paste('Determining number of surragate variables ...', Sys.time(), sep=' '))
n.sv <- num.sv(x$counts, mod, method="be")

print(paste('Fitting SV model ...', Sys.time(), sep=' '))
svobj <- svaseq(x$counts, mod, null.model, n.sv=n.sv)
# Out:
# [1] "Determining number of surragate variables ... 2020-03-05 17:10:01"
# [1] "Fitting SV model ... 2020-03-05 17:19:05"
# Number of significant surrogate variables is:  1
# Iteration (out of 5 ):1  2  3  4  5

# %% [markdown]
# ### Merge models

# %%
print(paste('Adding SV to design matrix ...', Sys.time(), sep=' '))
modQsva <- cbind(mod, svobj$sv)
len.d <- length(colnames(modQsva))
colnames(modQsva)[((len.d - n.sv)+1):len.d] <- make.names(paste0("sv",1:n.sv))
# Out:
# [1] "Adding SV to design matrix ... 2020-03-05 17:20:09"

# %% [markdown]
# ### Preform voom

# %%
v <- voom(x, modQsva, plot=TRUE)
# Out:
# Plot with title "voom: Mean-variance trend"

# %% [markdown]
# ### Calculate residuals

# %%
null_model = as.matrix(as.data.frame(v$design)[, !(names(as.data.frame(v$design)) %in% c("Male", "SCZ", "SCZ_Male"))])
fit_res <- lmFit(v, design=null_model)
res = v$E - ( fit_res$coefficients %*% t(null_model) )
res_sd = apply(res, 1, sd)
res_mean = apply(res, 1, mean)

# %% [markdown]
# ### Normalize residuals and write to file

# %%
res_norm = (res - res_mean) / res_sd

# %%
feature = 'genes'
dir.create(feature)
write.table(res_norm, file=paste0(feature, '/residualized_expression.tsv'), sep="\t", quote=FALSE)

# %% [markdown]
# ### Fit model with limma

# %%
fit0 <- lmFit(v, modQsva)
contr.matrix <- makeContrasts(CtrlvsSZ = SCZ,
                              MvsF = Male, 
                              Interaction = SCZ_Male,
                              levels=colnames(modQsva))
fit <- contrasts.fit(fit0, contrasts=contr.matrix)

# %% [markdown]
# ### Calculate differential expression with eBayes

# %% [markdown]
# #### SZ vs Ctrl

# %%
esv <- eBayes(fit)

options(width=200)
top0 <- topTable(esv, coef=1, number=Inf, sort.by="P")
sigTest <- decideTests(esv)

top <- merge(top0, sigTest, by=0)
rownames(top) <- top$Row.names
top <- top[,-1]
top <- top[order(top$P.Value), ]
dim(top)
# Out:
# [1] 25373    18

# %%
write.table(top, file=paste0(feature, "/diffExpr_szVctl_full.txt"),
            sep='\t', row.names=TRUE, quote=FALSE)

# %% [markdown]
# **Subset via FDR**

# %%
top.fdr <- top[top$adj.P.Val<=0.05,]
print(paste('There are:', dim(top.fdr)[1], 'DE features!'))
# Out:
# [1] "There are: 890 DE features!"
#                    Length gencodeID          ensemblID       gene_type      Symbol EntrezID Class meanExprs NumTx logFC      AveExpr  t         P.Value      adj.P.Val   B        CtrlvsSZ MvsF
# ENSG00000180176.14 3243   ENSG00000180176.14 ENSG00000180176 protein_coding TH     7054     InGen 0.4461342 11    -0.7964448 1.152069 -4.641203 4.824448e-06 0.001211987 3.713229 -1       0
#                    Interaction
# ENSG00000180176.14 0

# %%
write.table(top.fdr, file=paste0(feature, "/diffExpr_szVctl_FDR05.txt"),
            sep='\t', row.names=TRUE, quote=FALSE)

# %% [markdown]
# #### Male vs Female

# %%
top0 <- topTable(esv, coef=2, number=Inf, sort.by="P")
sigTest <- decideTests(esv)

top <- merge(top0, sigTest, by=0)
rownames(top) <- top$Row.names
top <- top[,-1]
top <- top[order(top$P.Value), ]
dim(top)
# Out:
# [1] 25373    18

# %%
write.table(top, file=paste0(feature, "/diffExpr_maleVfemale_full.txt"),
            sep='\t', row.names=TRUE, quote=FALSE)

# %% [markdown]
# **Subset via FDR**

# %%
top.fdr <- top[top$adj.P.Val<=0.05,]
print(paste('There are:', dim(top.fdr)[1], 'DE features!'))
# Out:
# [1] "There are: 156 DE features!"
#                    Length gencodeID          ensemblID       gene_type Symbol EntrezID Class meanExprs NumTx logFC     AveExpr  t         P.Value       adj.P.Val     B        CtrlvsSZ MvsF
# ENSG00000229807.10 19961  ENSG00000229807.10 ENSG00000229807 lincRNA   XIST   7503     InGen 8.103864  11    -9.134986 3.349947 -78.57403 4.189285e-232 5.314736e-228 521.3134 0        -1
#                    Interaction
# ENSG00000229807.10 0

# %%
write.table(top.fdr, file=paste0(feature, "/diffExpr_maleVfemale_FDR05.txt"),
            sep='\t', row.names=TRUE, quote=FALSE)

# %% [markdown]
# #### Interaction

# %%
top0 <- topTable(esv, coef=3, number=Inf, sort.by="P")
sigTest <- decideTests(esv)

top <- merge(top0, sigTest, by=0)
rownames(top) <- top$Row.names
top <- top[,-1]
top <- top[order(top$P.Value), ]
dim(top)
# Out:
# [1] 25373    18

# %%
write.table(top, file=paste0(feature, "/diffExpr_interaction_full.txt"),
            sep='\t', row.names=TRUE, quote=FALSE)

# %% [markdown]
# **Subset via FDR**

# %%
top.fdr <- top[top$adj.P.Val<=0.05,]
print(paste('There are:', dim(top.fdr)[1], 'DE features!'))
# Out:
# [1] "There are: 0 DE features!"

# %%
write.table(top.fdr, file=paste0(feature, "/diffExpr_interaction_FDR05.txt"),
            sep='\t', row.names=TRUE, quote=FALSE)

# %% [markdown]
# ## Volcano and MA plots

# %%
with(top, plot(logFC, -log10(P.Value), pch=20, cex=0.6))
with(subset(top, adj.P.Val<=0.05), points(logFC, -log10(P.Value),
                                          pch=20, col='red', cex=0.6))
with(subset(top, abs(logFC)>0.50), points(logFC, -log10(P.Value),
                                          pch=20, col='orange', cex=0.6))
with(subset(top, adj.P.Val<=0.05 & abs(logFC)>0.50),
     points(logFC, -log10(P.Value), pch=20, col='green', cex=0.6))
# Out:
# plot without title

# %%
pdf(file=paste0(feature, "/volcanoPlot.pdf"), 8, 6)
with(top, plot(logFC, -log10(P.Value), pch=20, cex=0.6))
with(subset(top, adj.P.Val<=0.05), points(logFC, -log10(P.Value),
                                          pch=20, col='red', cex=0.6))
with(subset(top, abs(logFC)>0.50), points(logFC, -log10(P.Value),
                                          pch=20, col='orange', cex=0.6))
with(subset(top, adj.P.Val<=0.05 & abs(logFC)>0.50),
     points(logFC, -log10(P.Value), pch=20, col='green', cex=0.6))
dev.off()
# Out:
# png
#   2

# %%
with(top, plot(AveExpr, logFC, pch=20, cex=0.5))
with(subset(top, adj.P.Val<0.05),
     points(AveExpr, logFC, col="red", pch=20, cex=0.5))
# Out:
# plot without title

# %%
pdf(file=paste0(feature, "/MAplot.pdf"), 8, 6)
with(top, plot(AveExpr, logFC, pch=20, cex=0.5))
with(subset(top, adj.P.Val<0.05),
     points(AveExpr, logFC, col="red", pch=20, cex=0.5))
dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Repreducibility Information

# %%
Sys.time()
proc.time()
options(width = 120)
sessioninfo::session_info()
# Out:
# [1] "2019-06-06 15:35:17 EDT"
#     user   system  elapsed
# 3161.182   47.897  287.152
# - Session info -------------------------------------------------------------------------------------------------------
#  setting  value
#  version  R version 3.5.0 (2018-04-23)
#  os       Arch Linux
#  system   x86_64, linux-gnu
#  ui       X11
#  language (EN)
#  collate  C
#  ctype    C
#  tz       America/New_York
#  date     2019-06-06
#
# - Packages -----------------------------------------------------------------------------------------------------------
#  package              * version   date       lib source
#  annotate               1.60.0    2018-10-30 [1] Bioconductor
#  AnnotationDbi          1.44.0    2018-10-30 [1] Bioconductor
#  assertthat             0.2.0     2017-04-11 [1] CRAN (R 3.5.0)
#  base64enc              0.1-3     2015-07-28 [1] CRAN (R 3.5.0)
#  bindr                  0.1.1     2018-03-13 [1] CRAN (R 3.5.0)
#  bindrcpp               0.2.2     2018-03-29 [1] CRAN (R 3.5.0)
#  Biobase              * 2.42.0    2018-10-30 [1] Bioconductor
#  BiocGenerics         * 0.28.0    2018-10-30 [1] Bioconductor
#  BiocParallel         * 1.16.2    2018-11-28 [1] Bioconductor
#  bit                    1.1-14    2018-05-29 [1] CRAN (R 3.5.0)
#  bit64                  0.9-7     2017-05-08 [1] CRAN (R 3.5.0)
#  bitops                 1.0-6     2013-08-17 [1] CRAN (R 3.5.0)
#  blob                   1.1.1     2018-03-25 [1] CRAN (R 3.5.0)
#  calibrate            * 1.7.2     2013-09-10 [1] CRAN (R 3.5.0)
#  cli                    1.0.1     2018-09-25 [1] CRAN (R 3.5.0)
#  colorspace             1.3-2     2016-12-14 [1] CRAN (R 3.5.0)
#  crayon                 1.3.4     2017-09-16 [1] CRAN (R 3.5.0)
#  DBI                    1.0.0     2018-05-02 [1] CRAN (R 3.5.0)
#  DelayedArray         * 0.8.0     2018-10-30 [1] Bioconductor
#  digest                 0.6.18    2018-10-10 [1] CRAN (R 3.5.0)
#  dplyr                  0.7.8     2018-11-10 [1] CRAN (R 3.5.0)
#  edgeR                * 3.24.1    2018-12-03 [1] Bioconductor
#  evaluate               0.12      2018-10-09 [1] CRAN (R 3.5.0)
#  genefilter           * 1.64.0    2018-10-30 [1] Bioconductor
#  GenomeInfoDb         * 1.18.1    2018-11-12 [1] Bioconductor
#  GenomeInfoDbData       1.2.0     2018-11-10 [1] Bioconductor
#  GenomicRanges        * 1.34.0    2018-10-30 [1] Bioconductor
#  ggplot2              * 3.1.0     2018-10-25 [1] CRAN (R 3.5.0)
#  glue                   1.3.0     2018-07-17 [1] CRAN (R 3.5.0)
#  gtable                 0.2.0     2016-02-26 [1] CRAN (R 3.5.0)
#  htmltools              0.3.6     2017-04-28 [1] CRAN (R 3.5.0)
#  IRanges              * 2.16.0    2018-10-30 [1] Bioconductor
#  IRdisplay              0.7.0     2018-11-29 [1] CRAN (R 3.5.0)
#  IRkernel               0.8.14    2018-11-16 [1] CRAN (R 3.5.0)
#  jsonlite               1.5       2017-06-01 [1] CRAN (R 3.5.0)
#  labeling               0.3       2014-08-23 [1] CRAN (R 3.5.0)
#  lattice                0.20-35   2017-03-25 [2] CRAN (R 3.5.0)
#  lazyeval               0.2.1     2017-10-29 [1] CRAN (R 3.5.0)
#  limma                * 3.38.3    2018-12-02 [1] Bioconductor
#  locfit                 1.5-9.1   2013-04-20 [1] CRAN (R 3.5.0)
#  magrittr               1.5       2014-11-22 [1] CRAN (R 3.5.0)
#  MASS                 * 7.3-51.1  2018-11-01 [1] CRAN (R 3.5.0)
#  Matrix                 1.2-14    2018-04-13 [2] CRAN (R 3.5.0)
#  matrixStats          * 0.54.0    2018-07-23 [1] CRAN (R 3.5.0)
#  memoise                1.1.0     2017-04-21 [1] CRAN (R 3.5.0)
#  mgcv                 * 1.8-23    2018-01-21 [2] CRAN (R 3.5.0)
#  munsell                0.5.0     2018-06-12 [1] CRAN (R 3.5.0)
#  nlme                 * 3.1-137   2018-04-07 [2] CRAN (R 3.5.0)
#  pbdZMQ                 0.3-3     2018-05-05 [1] CRAN (R 3.5.0)
#  pillar                 1.3.0     2018-07-14 [1] CRAN (R 3.5.0)
#  pkgconfig              2.0.2     2018-08-16 [1] CRAN (R 3.5.0)
#  plyr                   1.8.4     2016-06-08 [1] CRAN (R 3.5.0)
#  purrr                  0.2.5     2018-05-29 [1] CRAN (R 3.5.0)
#  R6                     2.3.0     2018-10-04 [1] CRAN (R 3.5.0)
#  Rcpp                   1.0.0     2018-11-07 [1] CRAN (R 3.5.0)
#  RCurl                  1.95-4.11 2018-07-15 [1] CRAN (R 3.5.0)
#  repr                   0.18      2018-11-27 [1] CRAN (R 3.5.0)
#  rlang                  0.3.0.1   2018-10-25 [1] CRAN (R 3.5.0)
#  RSQLite                2.1.1     2018-05-06 [1] CRAN (R 3.5.0)
#  S4Vectors            * 0.20.1    2018-11-09 [1] Bioconductor
#  scales                 1.0.0     2018-08-09 [1] CRAN (R 3.5.0)
#  sessioninfo            1.1.1     2018-11-05 [1] CRAN (R 3.5.0)
#  SummarizedExperiment * 1.12.0    2018-10-30 [1] Bioconductor
#  survival               2.41-3    2017-04-04 [2] CRAN (R 3.5.0)
#  sva                  * 3.30.0    2018-10-30 [1] Bioconductor
#  tibble                 1.4.2     2018-01-22 [1] CRAN (R 3.5.0)
#  tidyselect             0.2.5     2018-10-11 [1] CRAN (R 3.5.0)
#  uuid                   0.1-2     2015-07-28 [1] CRAN (R 3.5.0)
#  withr                  2.1.2     2018-03-15 [1] CRAN (R 3.5.0)
#  XML                    3.98-1.16 2018-08-19 [1] CRAN (R 3.5.0)
#  xtable                 1.8-3     2018-08-29 [1] CRAN (R 3.5.0)
#  XVector                0.22.0    2018-10-30 [1] Bioconductor
#  zlibbioc               1.28.0    2018-10-30 [1] Bioconductor
#
# [1] /home/jbenja13/R/x86_64-pc-linux-gnu-library/3.5
# [2] /usr/lib/R/library
